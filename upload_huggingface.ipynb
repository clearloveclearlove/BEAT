# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
from huggingface_hub import HfApi
api = HfApi()

api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Llama-3.1-8B_long",
    repo_id="BEAT-LLM-Backdoor/Llama-3.1-8B_long",
    repo_type="model",
)


api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Llama-3.1-8B_word",
    repo_id="BEAT-LLM-Backdoor/Llama-3.1-8B_word",
    repo_type="model",
)

api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Llama-3.1-8B_phrase",
    repo_id="BEAT-LLM-Backdoor/Llama-3.1-8B_phrase",
    repo_type="model",
)


api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Mistral-3-7B_long",
    repo_id="BEAT-LLM-Backdoor/Mistral-3-7B_long",
    repo_type="model",
)


api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Mistral-3-7B_word",
    repo_id="BEAT-LLM-Backdoor/Mistral-3-7B_word",
    repo_type="model",
)

api.upload_folder(
    folder_path="D:/code/PTM/Poisoned_Models/Mistral-3-7B_phrase",
    repo_id="BEAT-LLM-Backdoor/Mistral-3-7B_phrase",
    repo_type="model",
)
